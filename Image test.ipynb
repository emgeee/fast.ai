# %% [markdown]
# # Messing around with displaying images

# %%
# %matplotlib inline

# %% [markdown]
# This line is needed to display plots inline

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from PIL import Image

# %%
image_path = "data/dogscats/sample/valid/dogs/dog.5697.jpg"

# %%
im = Image.open(image_path)

# %%
print(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x374 at 0x7FA63E294860>

# %%
plt.imshow(im)
